# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nikhil Kumar
# *Student

# %% [markdown]
# *I am interested in data science because it is my passion

# %% [markdown]
# ### Add Two numbers

# %%
print(5+2)
# Out:
# 7

# %% [markdown]
# My Hobbies
# - play
# - read
# - code
